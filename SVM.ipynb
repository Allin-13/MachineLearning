# %% [markdown]
# <a href="https://colab.research.google.com/github/Allin-13/MachineLearning/blob/main/SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8d1e8e1d-3d14-473c-af07-21ae9742fc3a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8d1e8e1d-3d14-473c-af07-21ae9742fc3a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# ===============================================
# SPAM MAIL DETECTION USING SVM (FULL PROGRAM)
# ===============================================

# 1️⃣ Import Required Libraries
import pandas as pd
import numpy as np
import re
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# 2️⃣ Load Dataset (Make sure file is uploaded)
data = pd.read_csv("spam_ham_dataset.csv", encoding='latin-1')

print("Dataset Loaded Successfully!\n")
print("Columns in dataset:", data.columns)

# 3️⃣ Select Required Columns
data = data[['text', 'label_num']]

# 4️⃣ Clean Text Function
def clean_text(text):
    text = text.lower()
    text = re.sub(r'\W', ' ', text)
    text = re.sub(r'\d', '', text)
    text = re.sub(r'\s+', ' ', text)
    return text

data['text'] = data['text'].apply(clean_text)

print("\nText Cleaning Completed!")

# 5️⃣ Split Data into Training and Testing
X_train, X_test, y_train, y_test = train_test_split(
    data['text'],
    data['label_num'],
    test_size=0.2,
    random_state=42
)

print("Data Splitting Completed!")

# 6️⃣ Convert Text to TF-IDF Features
vectorizer = TfidfVectorizer(stop_words='english')

X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

print("TF-IDF Conversion Completed!")

# 7️⃣ Train SVM Model
model = SVC(kernel='linear')
model.fit(X_train_tfidf, y_train)

print("Model Training Completed!")

# 8️⃣ Predict on Test Data
y_pred = model.predict(X_test_tfidf)

# 9️⃣ Evaluate Model
print("\n==============================")
print("MODEL PERFORMANCE")
print("==============================")

print("Accuracy:", accuracy_score(y_test, y_pred))

print("\nConfusion Matrix:\n")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))

# 🔟 Manual User Input Testing
print("\n==============================")
print("MANUAL EMAIL TESTING")
print("==============================")

while True:
    user_input = input("\nEnter an email message (or type 'exit' to stop): ")

    if user_input.lower() == "exit":
        print("Program Ended.")
        break

    cleaned_input = clean_text(user_input)
    vector_input = vectorizer.transform([cleaned_input])
    prediction = model.predict(vector_input)

    if prediction[0] == 1:
        print("Prediction: Spam Mail")
    else:
        print("Prediction: Not Spam Mail")
# Out:
# Dataset Loaded Successfully!
#
# Columns in dataset: Index(['Unnamed: 0', 'label', 'text', 'label_num'], dtype='object')
#
# Text Cleaning Completed!
# Data Splitting Completed!
# TF-IDF Conversion Completed!
# Model Training Completed!
#
# ...
# MODEL PERFORMANCE
# ...
# Accuracy: 0.9893719806763285
#
# Confusion Matrix:
#
# [[735   7]
#  [  4 289]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       742
#            1       0.98      0.99      0.98       293
#
#     accuracy                           0.99      1035
#    macro avg       0.99      0.99      0.99      1035
# weighted avg       0.99      0.99      0.99      1035
#
#
# ...
# MANUAL EMAIL TESTING
# ...
#
# Enter an email message (or type 'exit' to stop): You won 50000 rupees click now
# Prediction: Spam Mail
#
# Enter an email message (or type 'exit' to stop): you have a meeting at 10 am
# Prediction: Not Spam Mail
